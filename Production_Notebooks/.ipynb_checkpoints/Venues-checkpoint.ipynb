# %% [markdown]
# ## College Football Data Wrangling
#
# #### The goal of this notebook is to pull in all the data from CollegeFootballData.com
# ##### Chris McAllister
# #### ----------------------------------
#
# ###### Helpful Tutorial
# https://blog.collegefootballdata.com/introduction-to-cfb-analytics/
#
# ###### Actual Documentation
# https://api.collegefootballdata.com/api/docs/?url=/api-docs.json
#
# ###### Get custom API key emailed here:
# https://collegefootballdata.com/key

# %%
import cfbd
import numpy as np
import pandas as pd

# %%
# Uncomment and run line below if cfbd library isn't already installed
#! pip install cfbd

# %%
# See link above to have custom API link emailed

api_key = 'jn8tnglKRmyayaeT0H3JG5TdxMxSnjLsFyW/QkRfhSS4UicMoNvZ71ao+gOXjMsI'

# %%
configuration = cfbd.Configuration()
configuration.api_key['Authorization'] = api_key
configuration.api_key_prefix['Authorization'] = 'Bearer'

api_config = cfbd.ApiClient(configuration)

# %% [markdown]
# #### Script to get every college football team, some attributes, and their name

# %%
teams_api = cfbd.TeamsApi(api_config)
teams = teams_api.get_fbs_teams()

df_teams = pd.DataFrame.from_records([t.to_dict() for t in teams])

df_teams
# Out:
#      id             school        mascot abbreviation alt_name_1 alt_name_2  \
# 0  2005          Air Force       Falcons          AFA       None       None
# 1  2006              Akron          Zips          AKR       None       None
# 2   333            Alabama  Crimson Tide          ALA       None       None
# 3  2026  Appalachian State  Mountaineers          APP       None       None
# 4    12            Arizona      Wildcats         ARIZ       None       None
#
#   alt_name_3 classification     conference  division    color alt_color  \
# 0       None           None  Mountain West  Mountain  #004a7b   #ffffff
# 1       None           None   Mid-American      East  #00285e   #84754e
# 2       None           None            SEC      West  #690014   #f1f2f3
# 3       None           None       Sun Belt      East  #000000   #ffcd00
# 4       None           None         Pac-12      None  #002449   #00205b
#
#                                                logos        twitter  \
# 0  [http://a.espncdn.com/i/teamlogos/ncaa/500/200...   @AF_Football
# 1  [http://a.espncdn.com/i/teamlogos/ncaa/500/200...        @ZipsFB
# 2  [http://a.espncdn.com/i/teamlogos/ncaa/500/333...   @AlabamaFTBL
# 3  [http://a.espncdn.com/i/teamlogos/ncaa/500/202...   @AppState_FB
# 4  [http://a.espncdn.com/i/teamlogos/ncaa/500/12....  @ArizonaFBall
#
#                                             location
# 0  {'venue_id': 3713, 'name': 'Falcon Stadium', '...
# 1  {'venue_id': 3768, 'name': 'Summa Field at Inf...
# 2  {'venue_id': 3657, 'name': 'Bryant Denny Stadi...
# 3  {'venue_id': 3792, 'name': 'Kidd Brewer Stadiu...
# 4  {'venue_id': 3619, 'name': 'Arizona Stadium', ...
